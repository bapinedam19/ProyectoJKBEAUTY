-- %% [markdown]
-- # [PROVEEDORES]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PROVEEDORES]    Script Date: 9/6/2021 16:27:52 ******/
CREATE DATABASE [PROVEEDORES]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PROVEEDORES', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\PROVEEDORES.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PROVEEDORES_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\PROVEEDORES_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [PROVEEDORES] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PROVEEDORES].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PROVEEDORES] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PROVEEDORES] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PROVEEDORES] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PROVEEDORES] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PROVEEDORES] SET ARITHABORT OFF 
GO
ALTER DATABASE [PROVEEDORES] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [PROVEEDORES] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PROVEEDORES] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PROVEEDORES] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PROVEEDORES] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PROVEEDORES] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PROVEEDORES] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PROVEEDORES] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PROVEEDORES] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PROVEEDORES] SET  ENABLE_BROKER 
GO
ALTER DATABASE [PROVEEDORES] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PROVEEDORES] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PROVEEDORES] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PROVEEDORES] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PROVEEDORES] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PROVEEDORES] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PROVEEDORES] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PROVEEDORES] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [PROVEEDORES] SET  MULTI_USER 
GO
ALTER DATABASE [PROVEEDORES] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PROVEEDORES] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PROVEEDORES] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PROVEEDORES] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PROVEEDORES] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PROVEEDORES] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [PROVEEDORES] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[proveedores]

-- %%
USE [PROVEEDORES]
GO

-- %%
/****** Object:  Table [dbo].[proveedores]    Script Date: 9/6/2021 16:27:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[proveedores](
	[cod_proveedor] [int] IDENTITY(1,1) NOT NULL,
	[nom_proveedor] [nvarchar](80) NOT NULL,
	[direccion_proveedor] [nvarchar](80) NOT NULL,
	[tel_propietario] [int] NOT NULL,
	[correo_proveedor] [nvarchar](80) NULL,
	[productos_proveedor] [nvarchar](80) NULL,
PRIMARY KEY CLUSTERED 
(
	[cod_proveedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [PROVEEDORES]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PROVEEDORES] SET  READ_WRITE 
GO
